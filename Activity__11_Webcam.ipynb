# %%
import cv2


# Define a object to access the webcam
ob = cv2.VideoCapture(0)


# Check if the camera opened successfully
if not ob.isOpened():
    print("Error")
    exit()
 
# Variables for gesture detection
backgound = None
accumulated_weight = 0.5
gesture_flag = False


# Loop to continuously capture and process video
while True:
    ret,frame = ob.read()
    
    if not ret:
        print("Error : could not read a frame.")
        break
        

        # convert the frame to the grayscale
    gray_frame = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    gray_frame = cv2.GaussianBlur(gray_frame,(21,21),0)

    if background is None:
        
        background = gray_frame.copy().astype("float")
        continue
        
   
# Calculate the absolute differnce between the current frame and
    cv2.accumulateWeighted(gray_frame,background,accumulated_weght)
    frame_delta = cv2.absdiff(gray_frame,cv2.convertScaleAbs(background))

# Apply thresholding to  the frame
    thresh = cv2.threshold(frame_delta,25,255,cv2.THRESH_BINRY)[1]
    thresh = cv2.dilate(thresh,None,iterations=2)


# Find contours in the threshold image
    contours,_= cv2.findContours(threshc.copy(cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE))
    for contours in contours:
         if cv2.contoursArea(contour)<1000:
                #Adjust the area threshold
                continue
         
         # gesture recoginition by movement
   
        (x,y,w,h) = cv2.boundingRect(contour)
        cv2.rectangle(frame,x(x,y),(x+w,y+h),(0,255,0),2)
        gesture_flag = True
        
     
 # Display frame in a window


  
    cv2.imshow("Video",frame)

    if cv2.waitkey(1) & 0*FF == ord('q'):
        break
    
        
        

    
# Close the window
ob.release()
cv2.destroyAllWindows()

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 4
#       2 # open an image using pillow
#       3 image_path = "E:\Pictures\Saved Pictures\Rishikesh\IMG_6659.HEIC.jpg"
# ----> 4 original_image = Image.open(image_path)
#       5 # display some information about the image
#       6 print("Original image format:", original_image.format)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# PermissionError: [Errno 13] Permission denied: 'E:\\Pictures\\Saved Pictures\\Rishikesh\\IMG_6659.HEIC.jpg'
